# %%
def display_game(positions):
    print("[ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]")
    print(positions)


def frog_game():
    positions = ['G', 'G', 'G', '-', 'B', 'B', 'B']

    while True:
        display_game(positions)

        user_input = input("Press 'q' to quit or enter position of piece: ")

        if user_input == 'q':
            print("You Lose")
            break

        selected_position = int(user_input)

        if selected_position < 0 or selected_position > 6:
            print("Invalid move")
            continue

        if positions[selected_position] == '-':
            print("Invalid Move")
            continue

        pos2 = 0

        if positions[selected_position] == 'G':
            if selected_position + 1 <= 6 and positions[selected_position + 1] == '-':
                pos2 = selected_position + 1
            elif selected_position + 2 <= 6 and positions[selected_position + 2] == '-' and positions[
                selected_position + 1] == 'B':
                pos2 = selected_position + 2
            else:
                print("Invalid Move")
                continue
        elif positions[selected_position] == 'B':
            if selected_position - 1 >= 0 and positions[selected_position - 1] == '-':
                pos2 = selected_position - 1
            elif selected_position - 2 >= 0 and positions[selected_position - 2] == '-' and positions[
                selected_position - 1] == 'G':
                pos2 = selected_position - 2
            else:
                print("Invalid Move")
                continue

        positions[selected_position], positions[pos2] = positions[pos2], positions[selected_position]

        if positions == ['B', 'B', 'B', '-', 'G', 'G', 'G']:
            display_game(positions)
            print("You Win!")
            break


if __name__ == "__main__":
    frog_game()
# Out:
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', 'G', 'G', '-', 'B', 'B', 'B']
# Press 'q' to quit or enter position of piece: 6
# Invalid Move
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', 'G', 'G', '-', 'B', 'B', 'B']
# Press 'q' to quit or enter position of piece: 2
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', 'G', '-', 'G', 'B', 'B', 'B']
# Press 'q' to quit or enter position of piece: 4
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', 'G', 'B', 'G', '-', 'B', 'B']
# Press 'q' to quit or enter position of piece: 5
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', 'G', 'B', 'G', 'B', '-', 'B']
# Press 'q' to quit or enter position of piece: 3
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', 'G', 'B', '-', 'B', 'G', 'B']
# Press 'q' to quit or enter position of piece: 5
# Invalid Move
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', 'G', 'B', '-', 'B', 'G', 'B']
# Press 'q' to quit or enter position of piece: 1
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', '-', 'B', 'G', 'B', 'G', 'B']
# Press 'q' to quit or enter position of piece: 3
# Invalid Move
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['G', '-', 'B', 'G', 'B', 'G', 'B']
# Press 'q' to quit or enter position of piece: 0
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['-', 'G', 'B', 'G', 'B', 'G', 'B']
# Press 'q' to quit or enter position of piece: 2
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['B', 'G', '-', 'G', 'B', 'G', 'B']
# Press 'q' to quit or enter position of piece: 4
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['B', 'G', 'B', 'G', '-', 'G', 'B']
# Press 'q' to quit or enter position of piece: 2
# Invalid Move
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['B', 'G', 'B', 'G', '-', 'G', 'B']
# Press 'q' to quit or enter position of piece: 3
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['B', 'G', 'B', '-', 'G', 'G', 'B']
# Press 'q' to quit or enter position of piece: 4
# Invalid Move
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['B', 'G', 'B', '-', 'G', 'G', 'B']
# Press 'q' to quit or enter position of piece: 2
# Invalid Move
# [ 0 , 1 , 2 , 3 , 4 , 5 , 6 ]
# ['B', 'G', 'B', '-', 'G', 'G', 'B']
# Press 'q' to quit or enter position of piece: q
# You Lose
